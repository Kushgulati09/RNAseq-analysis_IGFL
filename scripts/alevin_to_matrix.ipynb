# %%
from vpolo.alevin import parser
alevin_df = parser.read_quants_bin("/home/jovyan/ifbdata/spatial_cell_id/Kush/alignment/demo_matrix/SRR9036396")
# Out:
# /opt/conda/envs/spatialdata/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/jovyan/ifbdata/spatial_cell_id/Kush/alignment/demo_matrix/SRR9036396/alevin
# Using rust mode with 3281 rows and 78277 columns

# %%
alevin_df
# Out:
#                   ENSG00000290825.2  ENSG00000223972.6  ENSG00000310526.1  \
# CTTAACTTCTGAGGGA                0.0                0.0           0.000000
# AACACGTGTACAAGTA                0.0                0.0           1.500000
# AGAGCTTTCTTAACCT                0.0                0.0           0.000000
# TGGTTAGAGCAGACTG                0.0                0.0           0.000000
# CGGACGTCAACTGGCC                0.0                0.0           0.000000
# ...                             ...                ...                ...
# CAGTAACTCAGTCAGT                0.0                0.0           0.000000
# CGAGAAGAGAGCTGCA                0.0                0.0           0.000000
# CATCCACTCCAAACTG                0.0                0.0           0.333333
# CCCAGTTTCACTTACT                0.0                0.0           0.000000
# TACTTGTCAAGTCTGT                0.0                0.0           0.000000
#
#                   ENSG00000227232.6  ENSG00000278267.1  ENSG00000243485.6  \
# ...

# %%
import scanpy as sc

adata = sc.AnnData(alevin_df.T)
adata.write("alevin_matrix_aligned.h5ad")
# Out:
# /opt/conda/envs/spatialdata/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/envs/spatialdata/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/envs/spatialdata/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/envs/spatialdata/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
adata_1 = sc.read("alevin_matrix_aligned.h5ad")
print(adata_1)

# AnnData object with n_obs × n_vars = 78277 × 3281 (due to transpose)
# Out:
# /opt/conda/envs/spatialdata/lib/python3.10/site-packages/anndata/__init__.py:52: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# AnnData object with n_obs × n_vars = 78277 × 3281

# %%
alevin_df.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 row.names(alevin_df.T)
#
# NameError: name 'row' is not defined

# %%
# python indexing from 0
value = alevin_df.T.iloc[78274, 3]
value
# Out:
# 93.0

# %%
value = alevin_df.T.iloc[
[7821, 12738, 46417, 44704, 15278, 77174, 15752, 69137, 49181, 12322, 70482, 74487, 23640, 28812, 75216, 64102, 44736, 58222, 7352, 28042]
, 
[2569, 1902, 2391, 2527, 2613, 1206, 1001, 314, 562, 2650, 801, 984, 652, 3111, 191, 2243, 1656, 174, 2684, 1930]
]
value
# Out:
#                     TTGACTTAGCCAGAAC  TGCCAAAGTACCGTTA  CATCGGGTCCTAGTGA  \
# ENSG00000299677.1                0.0               0.0               0.0
# ENSG00000252017.1                0.0               0.0               0.0
# ENSG00000249695.6                0.0               0.0               0.0
# ENSG00000254972.1                0.0               0.0               0.0
# ENSG00000303819.1                0.0               0.0               0.0
# ENSG00000293661.1                0.0               0.0               0.0
# ENSG00000295304.1                0.0               0.0               0.0
# ENSG00000265954.1                0.0               0.0               0.0
# ENSG00000202249.1                0.0               0.0               0.0
# ENSG00000173692.14               0.0               0.0               0.0
# ENSG00000125813.15               0.0               0.0               0.0
# ENSG00000100341.13               0.0               0.0               0.0
# ...

# %%
alevin_df.T.shape
# Out:
# (78277, 3281)
